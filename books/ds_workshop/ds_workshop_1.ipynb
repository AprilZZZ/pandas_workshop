# %% [markdown]
# Гвидо ван Россум - 1990. Язык сверхвысокоуровневый, динамичный, объектно-ориентированный и кросс-платформенный.

# %% [markdown]
# "tab" - для завершения ввода (автоподстановка)
#
# ? - интроспекция, вывод документации для объекта
#
# ?? - исходный код функции, если это возможно
#
# xxx? - поиск по маске, например, np.load?
#
# %run - выполнить любой файл как python-программу в контексте текущего сеанса IPython. Скрипт выполняется в пустом пространстве имен, в которое ничего не импортировано и не определены никакие переменные (чтобы наоборот, нужно его запускать с ключом -i: %run -i). Все переменные, определенные в файле, будут доступны в оболочке IPython.

# %%
import this
# Out:
# The Zen of Python, by Tim Peters
#
# Beautiful is better than ugly.
# Explicit is better than implicit.
# Simple is better than complex.
# Complex is better than complicated.
# Flat is better than nested.
# Sparse is better than dense.
# Readability counts.
# Special cases aren't special enough to break the rules.
# Although practicality beats purity.
# Errors should never pass silently.
# Unless explicitly silenced.
# In the face of ambiguity, refuse the temptation to guess.
# There should be one-- and preferably only one --obvious way to do it.
# Although that way may not be obvious at first unless you're Dutch.
# Now is better than never.
# Although never is often better than *right* now.
# If the implementation is hard to explain, it's a bad idea.
# If the implementation is easy to explain, it may be a good idea.
# Namespaces are one honking great idea -- let's do more of those!

# %% [markdown]
# Встроенные структуры данных:
#
# () - кортеж
#
# [] - список (массив) - a collection of items that can be changed: .append() and .remove()
#
# {} - словарь (ассоциативный массив) - a collection of items that organized as a key-value pair, can be used to load JSON and converted into a Data Frame
#
# множества

# %%
# f-strings, very handy to print logs I like it :)
import numpy as np
x = np.random.randn(10).astype(np.float64).reshape(2, 5)
y = np.random.randn(10).astype(np.float64).reshape(5, 2)
print(f'first matrix:\n {x} \n second matrix: \n {y}, \n production x * y: \n {x @ y}')
# Out:
# first matrix:
#  [[ 0.27678605  1.44095516 -0.41030421  2.17159804  0.51968457]
#  [-1.11166764  1.64819064 -0.13814836 -1.02900725  0.34679145]]
#  second matrix:
#  [[ 1.898458   -0.24029656]
#  [ 0.11288026  1.28543284]
#  [-0.56341223  0.8766804 ]
#  [-0.8670218   0.51950218]
#  [ 0.21927641 -0.51655488]],
#  production x * y:
#  [[-0.8495758   2.285739  ]
#  [-0.87835677  1.550948  ]]

# %%
list1 = ['Packt', 15019, 2020, 'Data Science']
for item in list1:
    print(item)
# Out:
# Packt
# 15019
# 2020
# Data Science

# %%
dict1 = {'Topic': 'Data Science', 'Language': 'Python'}
print('dictionary:', dict1)
print('dictionary value for key \'Language:\'', dict1['Language'])
print(f'dictionary keys: {dict1.keys()} \ndictionary values: {dict1.values()}')
for key, value in dict1.items():
    print(key,':', value)
# Out:
# dictionary: {'Topic': 'Data Science', 'Language': 'Python'}
# dictionary value for key 'Language:' Python
# dictionary keys: dict_keys(['Topic', 'Language'])
# dictionary values: dict_values(['Data Science', 'Python'])
# Topic : Data Science
# Language : Python

# %%
algorithm = ['Linear Regression', 'Logistic Regression', 'RandomForest', 'a3c']
learning = ['Supervised', 'Supervised', 'Supervised', 'Reinforcement']
algorithm_type = ['Regression', 'Classification', 'Regression or Classification', 'Game AI']

# %%
algorithm.append('k-means')
learning.append('Unsupervised')
algorithm_type.append('Clustering')

# %%
machine_learning = {}
machine_learning['algorithm'] = algorithm
machine_learning['learning'] = learning
machine_learning['algorithm_type'] = algorithm_type

# %%
for key,value in machine_learning.items():
    print(key, ':', value)
# Out:
# algorithm : ['Linear Regression', 'Logistic Regression', 'RandomForest', 'k-means']
# learning : ['Supervised', 'Supervised', 'Supervised', 'Unsupervised']
# algorithm_type : ['Regression', 'Classification', 'Regression or Classification', 'Game AI', 'Clustering']

# %%
machine_learning['algorithm_type'].remove('Game AI')

# %%
machine_learning['learning'].remove('Reinforcement')

# %%
machine_learning
# Out:
# {'algorithm': ['Linear Regression',
#   'Logistic Regression',
#   'RandomForest',
#   'k-means'],
#  'learning': ['Supervised', 'Supervised', 'Supervised', 'Unsupervised'],
#  'algorithm_type': ['Regression',
#   'Classification',
#   'Regression or Classification',
#   'Clustering']}

# %%
df1 = pd.DataFrame.from_dict(machine_learning)
df1
# Out:
#              algorithm      learning                algorithm_type
# 0    Linear Regression    Supervised                    Regression
# 1  Logistic Regression    Supervised                Classification
# 2         RandomForest    Supervised  Regression or Classification
# 3              k-means  Unsupervised                    Clustering

# %%
import pandas as pd
data_path = '../The-Data-Science-Workshop/Chapter01/Dataset/'
pd.read_csv(data_path + 'csv_example.csv')
# Out:
#              algorithm      learning                          type
# 0    Linear Regression    Supervised                    Regression
# 1  Logistic Regression    Supervised                Classification
# 2         RandomForest    Supervised  Regression or Classification
# 3              k-means  Unsupervised                    Clustering

# %%
pd.read_excel(data_path + 'excel_example.xlsx')
# Out:
#              algorithm      learning                          type
# 0    Linear Regression    Supervised                    Regression
# 1  Logistic Regression    Supervised                Classification
# 2         RandomForest    Supervised  Regression or Classification
# 3              k-means  Unsupervised                    Clustering

# %%
pd.read_json(data_path + 'json_example.json')
# Out:
#              algorithm      learning                          type
# 0    Linear Regression    Supervised                    Regression
# 1  Logistic Regression    Supervised                Classification
# 2         RandomForest    Supervised  Regression or Classification
# 3              k-means  Unsupervised                    Clustering

# %%
csv_df = pd.read_csv(data_path + 'overall_topten_2012-2013.csv', skiprows=1)
csv_df
# Out:
#    Number  Postcode                                            Suburbs  \
# 0       1      3029                          Hoppers Crossing, Tarneit
# 1       2      3977                    Cranbourne, Devon Meadows, Skye
# 2       3      3064  Craigieburn, Donnybrook, Roxburgh Park, Mickleham
# 3       4      3030                     Point Cook, Werribee, Derrimut
# 4       5      3754                                     Doreen, Mernda
# 5       6      3810                                 Pakenham, Rythdale
# 6       7      3350  Alfredton, Ballarat, Canadian, Invermay Park, ...
# 7       8      3216  Belmont, Grovedale, Highton, Marshall, Waurn P...
# 8       9      3136  Croydon, Croydon Hills, Croydon North, Croydon...
# 9      10      3805    Fountain Gate, Narre Warren, Narre Warren South
#
#    Number of Applications
# 0                    1069
# 1                    1037
# 2                     821
# 3                     816
# 4                     530
# ...

# %%
tsv_df = pd.read_csv(data_path + 'overall_topten_2012-2013.tsv', skiprows=1, sep='\t')
tsv_df
# Out:
#    Number  Postcode                                            Suburbs  \
# 0       1      3029                          Hoppers Crossing, Tarneit
# 1       2      3977                    Cranbourne, Devon Meadows, Skye
# 2       3      3064  Craigieburn, Donnybrook, Roxburgh Park, Mickleham
# 3       4      3030                     Point Cook, Werribee, Derrimut
# 4       5      3754                                     Doreen, Mernda
# 5       6      3810                                 Pakenham, Rythdale
# 6       7      3350  Alfredton, Ballarat, Canadian, Invermay Park, ...
# 7       8      3216  Belmont, Grovedale, Highton, Marshall, Waurn P...
# 8       9      3136  Croydon, Croydon Hills, Croydon North, Croydon...
# 9      10      3805    Fountain Gate, Narre Warren, Narre Warren South
#
#    Number of Applications
# 0                    1069
# 1                    1037
# 2                     821
# 3                     816
# 4                     530
# ...

# %%
xlsx_df = pd.read_excel(data_path + 'overall_topten_2012-2013.xlsx', skiprows=1, sheet_name=1)
xlsx_df
# Out:
#    Number  Postcode                                            Suburbs  \
# 0       1      3029                          Hoppers Crossing, Tarneit
# 1       2      3977                    Cranbourne, Devon Meadows, Skye
# 2       3      3064  Craigieburn, Donnybrook, Roxburgh Park, Mickleham
# 3       4      3030                     Point Cook, Werribee, Derrimut
# 4       5      3754                                     Doreen, Mernda
# 5       6      3810                                 Pakenham, Rythdale
# 6       7      3350  Alfredton, Ballarat, Canadian, Invermay Park, ...
# 7       8      3216  Belmont, Grovedale, Highton, Marshall, Waurn P...
# 8       9      3136  Croydon, Croydon Hills, Croydon North, Croydon...
# 9      10      3805    Fountain Gate, Narre Warren, Narre Warren South
#
#    Number of Applications
# 0                    1069
# 1                    1037
# 2                     821
# 3                     816
# 4                     530
# ...

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score
data_path = 'https://raw.githubusercontent.com/PacktWorkshops/The-Data-Science-Workshop/master/Chapter01/Dataset/dataset_44_spambase.csv'
df = pd.read_csv(data_path)
targets = df.pop('class')

# %%
seed = 17
rf_model = RandomForestClassifier(random_state=seed)
rf_model.fit(df, targets)
# Out:
# RandomForestClassifier(random_state=17)

# %%
preds = rf_model.predict(df)
preds
# Out:
# array([1, 1, 1, ..., 0, 0, 0])

# %%
accuracy_score(targets, preds)
# Out:
# 0.9993479678330798

# %%
# display the graphics in the notebook environment
# %matplotlib inline
import matplotlib as mlp
import seaborn as sns
import matplotlib.pyplot as plt
import statsmodels.formula.api as smf
import statsmodels.graphics.api as smg
import pandas as pd
import numpy as np
import patsy
from statsmodels.graphics.correlation import plot_corr
from sklearn.model_selection import train_test_split
# to set the aesthetic look of the graphs that matplotlib generates to the type displayed by the seaborn module
plt.style.use('seaborn')

# %%
data_path = '../The-Data-Science-Workshop/Chapter02/Dataset/'
rawBostonData = pd.read_csv(data_path + 'Boston.csv')
rawBostonData.head()
# Out:
#       CRIM   ZN   INDUS   CHAS    NOX     RM   AGE     DIS  RAD  TAX  PTRATIO  \
# 0  0.00632  18.0    2.31     0  0.538  6.575  65.2  4.0900    1  296     15.3
# 1  0.02731   0.0    7.07     0  0.469  6.421  78.9  4.9671    2  242     17.8
# 2  0.02729   0.0    7.07     0  0.469  7.185  61.1  4.9671    2  242     17.8
# 3  0.03237   0.0    2.18     0  0.458  6.998  45.8  6.0622    3  222     18.7
# 4  0.06905   0.0    2.18     0  0.458  7.147  54.2  6.0622    3  222     18.7
#
#    LSTAT  MEDV
# 0   4.98  24.0
# 1   9.14  21.6
# 2   4.03  34.7
# 3   2.94  33.4
# 4   5.33  36.2

# %%
rawBostonData.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 13 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   CRIM     506 non-null    float64
#  1    ZN      506 non-null    float64
#  2   INDUS    506 non-null    float64
#  3   CHAS     506 non-null    int64
#  4   NOX      506 non-null    float64
#  5   RM       506 non-null    float64
#  6   AGE      506 non-null    float64
#  7   DIS      506 non-null    float64
#  8   RAD      506 non-null    int64
#  9   TAX      506 non-null    int64
#  10  PTRATIO  506 non-null    float64
#  11  LSTAT    506 non-null    float64
#  12  MEDV     506 non-null    float64
# dtypes: float64(10), int64(3)
# memory usage: 51.5 KB

# %%
# drop the missing value - null
rawBostonData = rawBostonData.dropna()
# drop duplicate records
rawBostonData = rawBostonData.drop_duplicates()

# %%
BostonData = rawBostonData.rename(columns = {'CRIM': 'crimePerCapita', 
                                             ' ZN ': 'landOver25K_sqft', 
                                             'INDUS ': 'non-retailLandProptn',
                                             'CHAS': 'riverDummy', 
                                             'NOX': 'nitrixOxide_pp10m', 
                                             'RM': 'AvgNo.RoomsPerDwelling',
                                             'AGE': 'ProptnOwnerOccupied', 
                                             'DIS': 'weightedDist', 
                                             'RAD': 'radialHighwaysAccess',
                                             'TAX': 'propTaxRate_per10K', 
                                             'PTRATIO': 'pupilTeacherRatio', 
                                             'LSTAT': 'pctLowerStatus',
                                             'MEDV': 'medianValue_Ks'})

# %%
BostonData.head()
# Out:
#    crimePerCapita  landOver25K_sqft  non-retailLandProptn  riverDummy  \
# 0         0.00632              18.0                  2.31           0
# 1         0.02731               0.0                  7.07           0
# 2         0.02729               0.0                  7.07           0
# 3         0.03237               0.0                  2.18           0
# 4         0.06905               0.0                  2.18           0
#
#    nitrixOxide_pp10m  AvgNo.RoomsPerDwelling  ProptnOwnerOccupied  \
# 0              0.538                   6.575                 65.2
# 1              0.469                   6.421                 78.9
# 2              0.469                   7.185                 61.1
# 3              0.458                   6.998                 45.8
# 4              0.458                   7.147                 54.2
#
#    weightedDist  radialHighwaysAccess  propTaxRate_per10K  pupilTeacherRatio  \
# ...

# %%
BostonData.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 506 entries, 0 to 505
# Data columns (total 13 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   crimePerCapita          506 non-null    float64
#  1   landOver25K_sqft        506 non-null    float64
#  2   non-retailLandProptn    506 non-null    float64
#  3   riverDummy              506 non-null    int64
#  4   nitrixOxide_pp10m       506 non-null    float64
#  5   AvgNo.RoomsPerDwelling  506 non-null    float64
#  6   ProptnOwnerOccupied     506 non-null    float64
#  7   weightedDist            506 non-null    float64
#  8   radialHighwaysAccess    506 non-null    int64
#  9   propTaxRate_per10K      506 non-null    int64
#  10  pupilTeacherRatio       506 non-null    float64
#  11  pctLowerStatus          506 non-null    float64
#  12  medianValue_Ks          506 non-null    float64
# dtypes: float64(10), int64(3)
# memory usage: 55.3 KB

# %%
# basic statistics for the numeric data
BostonData.describe(include=[np.number]).T
# Out:
#                         count        mean         std        min         25%  \
# crimePerCapita          506.0    3.613524    8.601545    0.00632    0.082045
# landOver25K_sqft        506.0   11.363636   23.322453    0.00000    0.000000
# non-retailLandProptn    506.0   11.136779    6.860353    0.46000    5.190000
# riverDummy              506.0    0.069170    0.253994    0.00000    0.000000
# nitrixOxide_pp10m       506.0    0.554695    0.115878    0.38500    0.449000
# AvgNo.RoomsPerDwelling  506.0    6.284634    0.702617    3.56100    5.885500
# ProptnOwnerOccupied     506.0   68.574901   28.148861    2.90000   45.025000
# weightedDist            506.0    3.795043    2.105710    1.12960    2.100175
# radialHighwaysAccess    506.0    9.549407    8.707259    1.00000    4.000000
# propTaxRate_per10K      506.0  408.237154  168.537116  187.00000  279.000000
# pupilTeacherRatio       506.0   18.455534    2.164946   12.60000   17.400000
# ...

# %%
# разделяем фичи и таргет
X = BostonData.drop('crimePerCapita', axis=1)
y = BostonData[['crimePerCapita']]

seed = 10
test_data_size = 0.3

# разделяем датасет на тренировочный и тестовый
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=test_data_size, random_state=seed)
train_data = pd.concat([X_train, y_train], axis=1)
test_data = pd.concat([X_test, y_test], axis=1)

# %%
# корреляционная матрица для тренировочного датасета
# может использоваться как начальная точка для дальнейшего регрессионного анализа
corrMatrix = train_data.corr(method='pearson')
xnames = list(train_data.columns)
ynames = list(train_data.columns)
plot_corr(corrMatrix, xnames=xnames, ynames=ynames, title=None, normcolor=False, cmap='RdYlBu_r')

# %%
train_data.corr(method='pearson')
# Out:
#                         landOver25K_sqft  non-retailLandProptn  riverDummy  \
# landOver25K_sqft                1.000000             -0.540095   -0.059189
# non-retailLandProptn           -0.540095              1.000000    0.065271
# riverDummy                     -0.059189              0.065271    1.000000
# nitrixOxide_pp10m              -0.520305              0.758178    0.091469
# AvgNo.RoomsPerDwelling          0.355346             -0.399166    0.107996
# ProptnOwnerOccupied            -0.577457              0.667887    0.106329
# weightedDist                    0.659340             -0.728968   -0.098551
# radialHighwaysAccess           -0.311920              0.580813    0.022731
# propTaxRate_per10K             -0.324172              0.702973   -0.007864
# pupilTeacherRatio              -0.424612              0.398513   -0.094255
# pctLowerStatus                 -0.435827              0.607457   -0.041110
# ...

# %%
# fig - define a canvas, ax - a graph object
# ci - the confidence interval
fig, ax = plt.subplots(figsize=(10, 6))
sns.regplot(x='medianValue_Ks', y='crimePerCapita', ci=None, data=train_data, 
            ax=ax, color='k', scatter_kws={'s': 20, 'color': 'royalblue', 'alpha': 1})
ax.set_ylabel('Crime rate per Capita', fontsize=15, fontname='DejaVu Sans')
ax.set_xlabel('Median value of owner-occupied homes in $1000\'s', fontsize=15, fontname='DejaVu Sans')
ax.set_xlim(left=None, right=None)
ax.set_ylim(bottom=None, top=30)
ax.tick_params(axis='both', which='major', labelsize=12)
fig.tight_layout()

# %%
# Examining a Possible Log-Linear Relationship
y = np.log(train_data['crimePerCapita'])
fig, ax = plt.subplots(figsize=(10, 6))
sns.regplot(x='medianValue_Ks', y=y, ci=95, data=train_data, ax=ax, color='k',
            scatter_kws={'s': 20, 'color': 'royalblue', 'alpha': 1})
ax.set_ylabel('Crime rate per Capita', fontsize=15, fontname='DejaVu Sans')
ax.set_xlabel('Median value of owner-occupied homes in $1000\'s', fontsize=15, fontname='DejaVu Sans')
ax.set_xlim(left=None, right=None)
ax.set_ylim(bottom=None, top=None)
ax.tick_params(axis='both', which='major', labelsize=12)
fig.tight_layout()
# we can see, that the regression line in the log graph more clearly matches the spread of the data points
# The transformeddependent variable (log of crime rate per capita) has an improved linear relationship
# with the median value of owner-occupied homes than the untransformed variable.

# %%
# how can we find the intercept and the slope of the straight-line relationship?
# we use patsy formula string to set the formula argument, '~' (tilda) is used to relate the dependent variable to the independent variable  
linearModel1 = smf.ols(formula='crimePerCapita ~ medianValue_Ks', data=train_data)
linearModelResult = linearModel1.fit()
print(linearModelResult.summary())
# y ≈ 11.2094 - 0.3502x, is the equation for our model
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:         crimePerCapita   R-squared:                       0.144
# Model:                            OLS   Adj. R-squared:                  0.141
# Method:                 Least Squares   F-statistic:                     59.02
# Date:                Tue, 25 May 2021   Prob (F-statistic):           1.56e-13
# Time:                        07:53:03   Log-Likelihood:                -1217.4
# No. Observations:                 354   AIC:                             2439.
# Df Residuals:                     352   BIC:                             2447.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                      coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# Intercept         11.2094      1.079     10.386      0.000       9.087      13.332
# ...

# %%
# statsmodels implements the R-style formula language, by using the Patsy Python library internally
# so statistical models can be easily defined
# on page 63 see a summary of the Patsy formula syntax and examples

# %%
linearModel2 = smf.ols(formula='np.log(crimePerCapita) ~ medianValue_Ks', data=train_data)
linearModelResult = linearModel2.fit()
print(linearModelResult.summary())
# Out:
#                               OLS Regression Results
# ...
# Dep. Variable:     np.log(crimePerCapita)   R-squared:                       0.238
# Model:                                OLS   Adj. R-squared:                  0.236
# Method:                     Least Squares   F-statistic:                     109.9
# Date:                    Tue, 25 May 2021   Prob (F-statistic):           1.48e-22
# Time:                            08:07:23   Log-Likelihood:                -727.67
# No. Observations:                     354   AIC:                             1459.
# Df Residuals:                         352   BIC:                             1467.
# Df Model:                               1
# Covariance Type:                nonrobust
# ...
#                      coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# Intercept          1.9107      0.271      7.062      0.000       1.379       2.443
# ...

# %%
# Multiple Linear Regression Model
multyLinearModel = smf.ols(formula='crimePerCapita ~ pctLowerStatus + radialHighwaysAccess + medianValue_Ks + nitrixOxide_pp10m', data=train_data)
multyLinearModelResult = multyLinearModel.fit()
print(multyLinearModelResult.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:         crimePerCapita   R-squared:                       0.398
# Model:                            OLS   Adj. R-squared:                  0.391
# Method:                 Least Squares   F-statistic:                     57.77
# Date:                Tue, 25 May 2021   Prob (F-statistic):           2.19e-37
# Time:                        08:26:59   Log-Likelihood:                -1154.9
# No. Observations:                 354   AIC:                             2320.
# Df Residuals:                     349   BIC:                             2339.
# Df Model:                           4
# Covariance Type:            nonrobust
# ...
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# Intercept                0.8912      2.670      0.334      0.739      -4.360       6.142
# ...

# %%
# When only one independent variable was used to create a model that seeks to explain 
# the variability in crimeRatePerCapita, the R-squared value calculated was only 14.4 percent.
# In this exercise, we used four independent variables. The model that was created improved
# the adjusted R-squared statistic to 39.1 percent, an increase of 24.7 percent.

# %%
# If we denote pctLowerStatus by x1, radialHighwaysAccess by x2, medianValue_Ks by x3 , and nitrixOxide_pp10m by x4, 
# a mathematical expression for the model created can be written as 
# y ≈ 0.8912+0.1028x1+0.4948x2-0.1103x3-2.1039x4

# %% [markdown]
# The main assumptions of linear regression analysis that we must ensure are met in order to develop a good model:
# 1. The relationship between the dependent and independent variables must be linear and additive.
# 2. The residual terms (ϵi) must be normally distributed. This is so that the standard error of estimate is calculated correctly.
# 3. The residual terms (ϵi) must have constant variance (homoskedasticity).
# 4. The residual terms (ϵi) must not be correlated.
# 5. There must not be correlation among the independent variables. When the independent variables are correlated among themselves, we have a problem called multicollinearity.

# %% [markdown]
# **TSS** (Total Sum of Squares) gives us a measure of the total variance found in the dependent variable from its mean value.
#
# **RSS** (Regression sum of squares) gives us a measure of the amount of variability in the dependent variable that our model explains.
# In practice we create models that are not perfect, so RSS is less than TSS. The missing amount by which RSS falls short of TSS is the amount of variability in the dependent variable that our regression model is not able to explain.
#
# That quantity is the Error Sum of Squares (**ESS**), which is essentially the sum of the residual terms of our model.
#
# **R-squared** is the ratio of RSS to TSS. This gives usa percentage measure of how much variability our regression model is able to explain compared to the total variability in the dependent variable with respect to the mean.
#
# **Adjusted R2** is used to select between models defined for the same dependent variable. It will increase only when the addition of an independent variable to the model contributes to explaining the variability in the dependent variable in a meaningful way.

# %% [markdown]
# **The regression analysis workflow is iterative.**
#
# You start by plotting to get a visual picture and follow from there to improve upon the model you finally develop by using different techniques. Once a good model has been developed, the next step is to validate the model statistically before it can be used for making a prediction or acquiring insight for decision making.
