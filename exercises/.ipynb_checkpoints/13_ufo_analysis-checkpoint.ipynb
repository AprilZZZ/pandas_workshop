# %%
import pandas as pd
from datetime import datetime as dt
from datetime import timedelta

# %% [markdown]
# # Pandas Datetime [25 exercises with solution]

# %%
df = pd.read_csv('data/ufo_sighting_data.csv', 
                 parse_dates=[0, 8], 
                 dtype={'length_of_encounter_seconds': 'str',
                        'latitude': 'str'})
df.columns = df.columns.str.lower().str.replace(' ', '_')
df.head(5)
# Out:
#           date_time                  city state/province country ufo_shape  \
# 0  10/10/1949 20:30            san marcos             tx      us  cylinder
# 1  10/10/1949 21:00          lackland afb             tx     NaN     light
# 2  10/10/1955 17:00  chester (uk/england)            NaN      gb    circle
# 3  10/10/1956 21:00                  edna             tx      us    circle
# 4  10/10/1960 20:00               kaneohe             hi      us     light
#
#   length_of_encounter_seconds described_duration_of_encounter  \
# 0                        2700                      45 minutes
# 1                        7200                         1-2 hrs
# 2                          20                      20 seconds
# 3                          20                        1/2 hour
# 4                         900                      15 minutes
#
#                                          description date_documented  \
# 0  This event took place in early fall around 194...      2004-04-27
# 1  1949 Lackland AFB&#44 TX.  Lights racing acros...      2005-12-16
# 2  Green/Orange circular disc over Chester&#44 En...      2008-01-21
# 3  My older brother and twin sister were leaving ...      2004-01-17
# 4  AS a Marine 1st Lt. flying an FJ4B fighter/att...      2004-01-22
#
#      latitude   longitude
# 0  29.8830556  -97.941111
# 1    29.38421  -98.581082
# 2        53.2   -2.916667
# 3  28.9783333  -96.645833
# 4  21.4180556 -157.803611

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 80332 entries, 0 to 80331
# Data columns (total 11 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   date_time                        80332 non-null  object
#  1   city                             80332 non-null  object
#  2   state/province                   74535 non-null  object
#  3   country                          70662 non-null  object
#  4   ufo_shape                        78400 non-null  object
#  5   length_of_encounter_seconds      80332 non-null  object
#  6   described_duration_of_encounter  80332 non-null  object
#  7   description                      80317 non-null  object
#  8   date_documented                  80332 non-null  datetime64[ns]
#  9   latitude                         80332 non-null  object
#  10  longitude                        80332 non-null  float64
# dtypes: datetime64[ns](1), float64(1), object(9)
# memory usage: 6.7+ MB

# %% [markdown]
# Наблюдаем проблемы:
# 1. Варнинг по колонкам 5, 9. Нужно корректно разобраться в ситуации.
# 2. Поле date_time не преобразовалось в тип даты. Нужно исследовать в чем проблема.
#
# **Кейс2**
# Попробуем явно преобразовать поле date_time. Получаем ошибку, из которой следует, что есть записи, у которых часы указаны некорректно: 24:00. Способ решения: выбрать записи с некорректным значением поля и преобразовать у них время на 0 часов следующего дня.

# %%
df.date_time.apply(lambda x: pd.to_datetime(x))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.9/site-packages/dateutil/parser/_parser.py in parse(self, timestr, default, ignoretz, tzinfos, **kwargs)
#     648         try:
# --> 649             ret = self._build_naive(res, default)
#     650         except ValueError as e:
#
# ~/opt/anaconda3/lib/python3.9/site-packages/dateutil/parser/_parser.py in _build_naive(self, res, default)
#    1234
# -> 1235         naive = default.replace(**repl)
#    1236
#
# ValueError: hour must be in 0..23
#
# The above exception was the direct cause of the following exception:
#
# ParserError                               Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/_libs/tslib.pyx in pandas._libs.tslib.array_to_datetime()
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/_libs/tslibs/parsing.pyx in pandas._libs.tslibs.parsing.parse_datetime_string()
#
# ~/opt/anaconda3/lib/python3.9/site-packages/dateutil/parser/_parser.py in parse(timestr, parserinfo, **kwargs)
#    1367     else:
# -> 1368         return DEFAULTPARSER.parse(timestr, **kwargs)
#    1369
#
# ~/opt/anaconda3/lib/python3.9/site-packages/dateutil/parser/_parser.py in parse(self, timestr, default, ignoretz, tzinfos, **kwargs)
#     650         except ValueError as e:
# --> 651             six.raise_from(ParserError(str(e) + ": %s", timestr), e)
#     652
#
# ~/opt/anaconda3/lib/python3.9/site-packages/six.py in raise_from(value, from_value)
#
# ParserError: hour must be in 0..23: 10/11/2006 24:00
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/_libs/tslib.pyx in pandas._libs.tslib.array_to_datetime()
#
# TypeError: invalid string coercion to datetime for "10/11/2006 24:00" at position 0
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.9/site-packages/dateutil/parser/_parser.py in parse(self, timestr, default, ignoretz, tzinfos, **kwargs)
#     648         try:
# --> 649             ret = self._build_naive(res, default)
#     650         except ValueError as e:
#
# ~/opt/anaconda3/lib/python3.9/site-packages/dateutil/parser/_parser.py in _build_naive(self, res, default)
#    1234
# -> 1235         naive = default.replace(**repl)
#    1236
#
# ValueError: hour must be in 0..23
#
# The above exception was the direct cause of the following exception:
#
# ParserError                               Traceback (most recent call last)
# /var/folders/lq/8xyjvtzs5m74h82472673s0h0000gn/T/ipykernel_51809/3165209864.py in <module>
# ----> 1 df.date_time.apply(lambda x: pd.to_datetime(x))
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/series.py in apply(self, func, convert_dtype, args, **kwargs)
#    4769         dtype: float64
#    4770         """
# -> 4771         return SeriesApply(self, func, convert_dtype, args, kwargs).apply()
#    4772
#    4773     def _reduce(
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/apply.py in apply(self)
#    1103
#    1104         # self.f is Callable
# -> 1105         return self.apply_standard()
#    1106
#    1107     def agg(self):
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/apply.py in apply_standard(self)
#    1154             else:
#    1155                 values = obj.astype(object)._values
# -> 1156                 mapped = lib.map_infer(
#    1157                     values,
#    1158                     f,
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/_libs/lib.pyx in pandas._libs.lib.map_infer()
#
# /var/folders/lq/8xyjvtzs5m74h82472673s0h0000gn/T/ipykernel_51809/3165209864.py in <lambda>(x)
# ----> 1 df.date_time.apply(lambda x: pd.to_datetime(x))
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/tools/datetimes.py in to_datetime(arg, errors, dayfirst, yearfirst, utc, format, exact, unit, infer_datetime_format, origin, cache)
#    1100             result = convert_listlike(argc, format)
#    1101     else:
# -> 1102         result = convert_listlike(np.array([arg]), format)[0]
#    1103         if isinstance(arg, bool) and isinstance(result, np.bool_):
#    1104             result = bool(result)  # TODO: avoid this kludge.
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/tools/datetimes.py in _convert_listlike_datetimes(arg, format, name, tz, unit, errors, infer_datetime_format, dayfirst, yearfirst, exact)
#     436     assert format is None or infer_datetime_format
#     437     utc = tz == "utc"
# --> 438     result, tz_parsed = objects_to_datetime64ns(
#     439         arg,
#     440         dayfirst=dayfirst,
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/arrays/datetimes.py in objects_to_datetime64ns(data, dayfirst, yearfirst, utc, errors, require_iso8601, allow_object, allow_mixed)
#    2175     order: Literal["F", "C"] = "F" if flags.f_contiguous else "C"
#    2176     try:
# -> 2177         result, tz_parsed = tslib.array_to_datetime(
#    2178             data.ravel("K"),
#    2179             errors=errors,
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/_libs/tslib.pyx in pandas._libs.tslib.array_to_datetime()
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/_libs/tslib.pyx in pandas._libs.tslib.array_to_datetime()
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/_libs/tslib.pyx in pandas._libs.tslib._array_to_datetime_object()
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/_libs/tslib.pyx in pandas._libs.tslib._array_to_datetime_object()
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/_libs/tslibs/parsing.pyx in pandas._libs.tslibs.parsing.parse_datetime_string()
#
# ~/opt/anaconda3/lib/python3.9/site-packages/dateutil/parser/_parser.py in parse(timestr, parserinfo, **kwargs)
#    1366         return parser(parserinfo).parse(timestr, **kwargs)
#    1367     else:
# -> 1368         return DEFAULTPARSER.parse(timestr, **kwargs)
#    1369
#    1370
#
# ~/opt/anaconda3/lib/python3.9/site-packages/dateutil/parser/_parser.py in parse(self, timestr, default, ignoretz, tzinfos, **kwargs)
#     649             ret = self._build_naive(res, default)
#     650         except ValueError as e:
# --> 651             six.raise_from(ParserError(str(e) + ": %s", timestr), e)
#     652
#     653         if not ignoretz:
#
# ~/opt/anaconda3/lib/python3.9/site-packages/six.py in raise_from(value, from_value)
#
# ParserError: hour must be in 0..23: 10/11/2006 24:00 present at position 0

# %% [markdown]
# Находим 694 строки с некорректным временем.

# %%
df.query('date_time.str.contains("24:00")')
# Out:
#               date_time                              city state/province  \
# 388    10/11/2006 24:00                              rome             ny
# 693     10/1/2001 24:00  chulucanas-piura la vieja (peru)            NaN
# 962     10/1/2012 24:00                              novi             mi
# 1067   10/12/2003 24:00              salatiga (indonesia)            NaN
# 1221   10/12/2013 24:00                        cincinnati             oh
# ...                 ...                               ...            ...
# 79136    9/4/2005 24:00                         boonville             nc
# 79137    9/4/2005 24:00                     redondo beach             ca
# 79740    9/7/2002 24:00                        portsmouth             oh
# 79759    9/7/2004 24:00                          montrose             co
# 79942    9/8/2003 24:00                      cedar rapids             ia
#
#       country ufo_shape length_of_encounter_seconds  \
# 388        us      oval                         120
# 693       NaN     other                     6312000
# 962        us  triangle                         300
# 1067      NaN      disk                          22
# 1221       us  fireball                         300
# ...       ...       ...                         ...
# 79136      us     cigar                     10800.0
# 79137      us  triangle                       300.0
# 79740      us  changing                       900.0
# 79759      us   unknown                      1200.0
# 79942      us  changing                       900.0
#
#       described_duration_of_encounter  \
# 388                      a min or two
# 693                           2 years
# 962                         5 minutes
# 1067                       22 seconds
# 1221                      3-5 minutes
# ...                               ...
# 79136                        3+ hours
# 79137                       5 minutes
# 79740                      15 minutes
# 79759                      20 minutes
# 79942                          15 min
#
#                                              description date_documented  \
# 388    I was walking from the garage to the house&#44...      2007-02-01
# 693    go to:  http://www.24horas.com.pe/data/videos/...      2003-03-04
# 962    V shaped and 8 big and very brite lights&#44mo...      2012-10-30
# 1067                        UFO in Salatiga&#44Indonesia      2003-10-31
# 1221   A bright orange light split into four&#44 did ...      2013-10-14
# ...                                                  ...             ...
# 79136  Unusual activity in our small community&#44 cr...      2013-09-09
# 79137  Triangulat UFO seen over Redondo Beach&#44 Cal...      2005-12-16
# 79740           A bright red light hoovering in the sky.      2002-09-13
# 79759  Stationary object with three pulsating lights ...      2004-09-09
# 79942                                         WE SEEN IT      2003-09-17
#
#          latitude   longitude
# 388    43.2127778  -75.456111
# 693     -5.129547  -80.120569
# 962    42.4805556  -83.475556
# 1067     -7.33683  110.498817
# 1221   39.1619444  -84.456944
# ...           ...         ...
# 79136     36.2325  -80.708333
# 79137   33.849167 -118.387500
# 79740   38.731667  -82.997778
# 79759   38.478333 -107.875556
# 79942   42.008333  -91.643889
#
# [694 rows x 11 columns]

# %% [markdown]
# Дополнительно проверим в каком формате указана дата в этом поле. Получаем неудобный для восприятия формат: m/d/Y.

# %%
df[['date', 'time']] = df.date_time.str.split(' ', expand=True)
df[['date1', 'date2', 'year']] = df.date.str.split('/', expand=True)

# %%
df[['date1', 'date2']].describe()
# Out:
#         date1  date2
# count   80332  80332
# unique     12     31
# top         7     15
# freq     9520   5968

# %% [markdown]
# Преобразуем поле data в тип даты в более удобном формате.

# %%
df['date'] = df.date.apply(lambda x: dt.strptime(x, '%m/%d/%Y'))
df.date
# Out:
# 0       1949-10-10
# 1       1949-10-10
# 2       1955-10-10
# 3       1956-10-10
# 4       1960-10-10
#            ...
# 80327   2013-09-09
# 80328   2013-09-09
# 80329   2013-09-09
# 80330   2013-09-09
# 80331   2013-09-09
# Name: date, Length: 80332, dtype: datetime64[ns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 80332 entries, 0 to 80331
# Data columns (total 16 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   date_time                        80332 non-null  object
#  1   city                             80332 non-null  object
#  2   state/province                   74535 non-null  object
#  3   country                          70662 non-null  object
#  4   ufo_shape                        78400 non-null  object
#  5   length_of_encounter_seconds      80332 non-null  object
#  6   described_duration_of_encounter  80332 non-null  object
#  7   description                      80317 non-null  object
#  8   date_documented                  80332 non-null  datetime64[ns]
#  9   latitude                         80332 non-null  object
#  10  longitude                        80332 non-null  float64
#  11  date                             80332 non-null  datetime64[ns]
#  12  time                             80332 non-null  object
#  13  date1                            80332 non-null  object
#  14  date2                            80332 non-null  object
#  15  year                             80332 non-null  object
# dtypes: datetime64[ns](2), float64(1), object(13)
# memory usage: 9.8+ MB

# %% [markdown]
# Выполним необходимое преобразование для строк с некорректным временем (24:00): к дате добавим один день, а время заменим на 0:00.

# %%
idx = df.query('date_time.str.contains("24:00")').index.to_list()
df.iloc[idx] = df.loc[idx].assign(
                            date=lambda x: x.date + timedelta(days=1),
                            time='00:00')

# %%
df.query('date_time.str.contains("24:00")')[['date_time', 'date', 'time']]
# Out:
#               date_time       date   time
# 388    10/11/2006 24:00 2006-10-12  00:00
# 693     10/1/2001 24:00 2001-10-02  00:00
# 962     10/1/2012 24:00 2012-10-02  00:00
# 1067   10/12/2003 24:00 2003-10-13  00:00
# 1221   10/12/2013 24:00 2013-10-13  00:00
# ...                 ...        ...    ...
# 79136    9/4/2005 24:00 2005-09-05  00:00
# 79137    9/4/2005 24:00 2005-09-05  00:00
# 79740    9/7/2002 24:00 2002-09-08  00:00
# 79759    9/7/2004 24:00 2004-09-08  00:00
# 79942    9/8/2003 24:00 2003-09-09  00:00
#
# [694 rows x 3 columns]

# %% [markdown]
# Добавим новую колонку datetime, объединяющую дату и время записи и сделаем ее индексом.

# %%
df = df.assign(datetime = lambda x: x.date + pd.to_timedelta(x.time + ':00'))
df.set_index('datetime', inplace=True)
df
# Out:
#                             date_time                  city state/province  \
# datetime
# 1949-10-10 20:30:00  10/10/1949 20:30            san marcos             tx
# 1949-10-10 21:00:00  10/10/1949 21:00          lackland afb             tx
# 1955-10-10 17:00:00  10/10/1955 17:00  chester (uk/england)            NaN
# 1956-10-10 21:00:00  10/10/1956 21:00                  edna             tx
# 1960-10-10 20:00:00  10/10/1960 20:00               kaneohe             hi
# ...                               ...                   ...            ...
# 2013-09-09 21:15:00    9/9/2013 21:15             nashville             tn
# 2013-09-09 22:00:00    9/9/2013 22:00                 boise             id
# 2013-09-09 22:00:00    9/9/2013 22:00                  napa             ca
# 2013-09-09 22:20:00    9/9/2013 22:20                vienna             va
# 2013-09-09 23:00:00    9/9/2013 23:00                edmond             ok
#
#                     country ufo_shape length_of_encounter_seconds  \
# datetime
# 1949-10-10 20:30:00      us  cylinder                        2700
# 1949-10-10 21:00:00     NaN     light                        7200
# 1955-10-10 17:00:00      gb    circle                          20
# 1956-10-10 21:00:00      us    circle                          20
# 1960-10-10 20:00:00      us     light                         900
# ...                     ...       ...                         ...
# 2013-09-09 21:15:00      us     light                       600.0
# 2013-09-09 22:00:00      us    circle                      1200.0
# 2013-09-09 22:00:00      us     other                      1200.0
# 2013-09-09 22:20:00      us    circle                         5.0
# 2013-09-09 23:00:00      us     cigar                      1020.0
#
#                     described_duration_of_encounter  \
# datetime
# 1949-10-10 20:30:00                      45 minutes
# 1949-10-10 21:00:00                         1-2 hrs
# 1955-10-10 17:00:00                      20 seconds
# 1956-10-10 21:00:00                        1/2 hour
# 1960-10-10 20:00:00                      15 minutes
# ...                                             ...
# 2013-09-09 21:15:00                      10 minutes
# 2013-09-09 22:00:00                      20 minutes
# 2013-09-09 22:00:00                            hour
# 2013-09-09 22:20:00                       5 seconds
# 2013-09-09 23:00:00                      17 minutes
#
#                                                            description  \
# datetime
# 1949-10-10 20:30:00  This event took place in early fall around 194...
# 1949-10-10 21:00:00  1949 Lackland AFB&#44 TX.  Lights racing acros...
# 1955-10-10 17:00:00  Green/Orange circular disc over Chester&#44 En...
# 1956-10-10 21:00:00  My older brother and twin sister were leaving ...
# 1960-10-10 20:00:00  AS a Marine 1st Lt. flying an FJ4B fighter/att...
# ...                                                                ...
# 2013-09-09 21:15:00  Round from the distance/slowly changing colors...
# 2013-09-09 22:00:00  Boise&#44 ID&#44 spherical&#44 20 min&#44 10 r...
# 2013-09-09 22:00:00                                       Napa UFO&#44
# 2013-09-09 22:20:00  Saw a five gold lit cicular craft moving fastl...
# 2013-09-09 23:00:00  2 witnesses 2  miles apart&#44 Red &amp; White...
#
#                     date_documented    latitude   longitude       date   time  \
# datetime
# 1949-10-10 20:30:00      2004-04-27  29.8830556  -97.941111 1949-10-10  20:30
# 1949-10-10 21:00:00      2005-12-16    29.38421  -98.581082 1949-10-10  21:00
# 1955-10-10 17:00:00      2008-01-21        53.2   -2.916667 1955-10-10  17:00
# 1956-10-10 21:00:00      2004-01-17  28.9783333  -96.645833 1956-10-10  21:00
# 1960-10-10 20:00:00      2004-01-22  21.4180556 -157.803611 1960-10-10  20:00
# ...                             ...         ...         ...        ...    ...
# 2013-09-09 21:15:00      2013-09-30   36.165833  -86.784444 2013-09-09  21:15
# 2013-09-09 22:00:00      2013-09-30   43.613611 -116.202500 2013-09-09  22:00
# 2013-09-09 22:00:00      2013-09-30   38.297222 -122.284444 2013-09-09  22:00
# 2013-09-09 22:20:00      2013-09-30   38.901111  -77.265556 2013-09-09  22:20
# 2013-09-09 23:00:00      2013-09-30   35.652778  -97.477778 2013-09-09  23:00
#
#                     date1 date2  year
# datetime
# 1949-10-10 20:30:00    10    10  1949
# 1949-10-10 21:00:00    10    10  1949
# 1955-10-10 17:00:00    10    10  1955
# 1956-10-10 21:00:00    10    10  1956
# 1960-10-10 20:00:00    10    10  1960
# ...                   ...   ...   ...
# 2013-09-09 21:15:00     9     9  2013
# 2013-09-09 22:00:00     9     9  2013
# 2013-09-09 22:00:00     9     9  2013
# 2013-09-09 22:20:00     9     9  2013
# 2013-09-09 23:00:00     9     9  2013
#
# [80332 rows x 16 columns]

# %% [markdown]
# Удалим вспомогательные колонки.

# %%
df.drop(['date', 'time', 'date1', 'date2', 'year'], axis=1, inplace=True)
df
# Out:
#                             date_time                  city state/province  \
# datetime
# 1949-10-10 20:30:00  10/10/1949 20:30            san marcos             tx
# 1949-10-10 21:00:00  10/10/1949 21:00          lackland afb             tx
# 1955-10-10 17:00:00  10/10/1955 17:00  chester (uk/england)            NaN
# 1956-10-10 21:00:00  10/10/1956 21:00                  edna             tx
# 1960-10-10 20:00:00  10/10/1960 20:00               kaneohe             hi
# ...                               ...                   ...            ...
# 2013-09-09 21:15:00    9/9/2013 21:15             nashville             tn
# 2013-09-09 22:00:00    9/9/2013 22:00                 boise             id
# 2013-09-09 22:00:00    9/9/2013 22:00                  napa             ca
# 2013-09-09 22:20:00    9/9/2013 22:20                vienna             va
# 2013-09-09 23:00:00    9/9/2013 23:00                edmond             ok
#
#                     country ufo_shape length_of_encounter_seconds  \
# datetime
# 1949-10-10 20:30:00      us  cylinder                        2700
# 1949-10-10 21:00:00     NaN     light                        7200
# 1955-10-10 17:00:00      gb    circle                          20
# 1956-10-10 21:00:00      us    circle                          20
# 1960-10-10 20:00:00      us     light                         900
# ...                     ...       ...                         ...
# 2013-09-09 21:15:00      us     light                       600.0
# 2013-09-09 22:00:00      us    circle                      1200.0
# 2013-09-09 22:00:00      us     other                      1200.0
# 2013-09-09 22:20:00      us    circle                         5.0
# 2013-09-09 23:00:00      us     cigar                      1020.0
#
#                     described_duration_of_encounter  \
# datetime
# 1949-10-10 20:30:00                      45 minutes
# 1949-10-10 21:00:00                         1-2 hrs
# 1955-10-10 17:00:00                      20 seconds
# 1956-10-10 21:00:00                        1/2 hour
# 1960-10-10 20:00:00                      15 minutes
# ...                                             ...
# 2013-09-09 21:15:00                      10 minutes
# 2013-09-09 22:00:00                      20 minutes
# 2013-09-09 22:00:00                            hour
# 2013-09-09 22:20:00                       5 seconds
# 2013-09-09 23:00:00                      17 minutes
#
#                                                            description  \
# datetime
# 1949-10-10 20:30:00  This event took place in early fall around 194...
# 1949-10-10 21:00:00  1949 Lackland AFB&#44 TX.  Lights racing acros...
# 1955-10-10 17:00:00  Green/Orange circular disc over Chester&#44 En...
# 1956-10-10 21:00:00  My older brother and twin sister were leaving ...
# 1960-10-10 20:00:00  AS a Marine 1st Lt. flying an FJ4B fighter/att...
# ...                                                                ...
# 2013-09-09 21:15:00  Round from the distance/slowly changing colors...
# 2013-09-09 22:00:00  Boise&#44 ID&#44 spherical&#44 20 min&#44 10 r...
# 2013-09-09 22:00:00                                       Napa UFO&#44
# 2013-09-09 22:20:00  Saw a five gold lit cicular craft moving fastl...
# 2013-09-09 23:00:00  2 witnesses 2  miles apart&#44 Red &amp; White...
#
#                     date_documented    latitude   longitude
# datetime
# 1949-10-10 20:30:00      2004-04-27  29.8830556  -97.941111
# 1949-10-10 21:00:00      2005-12-16    29.38421  -98.581082
# 1955-10-10 17:00:00      2008-01-21        53.2   -2.916667
# 1956-10-10 21:00:00      2004-01-17  28.9783333  -96.645833
# 1960-10-10 20:00:00      2004-01-22  21.4180556 -157.803611
# ...                             ...         ...         ...
# 2013-09-09 21:15:00      2013-09-30   36.165833  -86.784444
# 2013-09-09 22:00:00      2013-09-30   43.613611 -116.202500
# 2013-09-09 22:00:00      2013-09-30   38.297222 -122.284444
# 2013-09-09 22:20:00      2013-09-30   38.901111  -77.265556
# 2013-09-09 23:00:00      2013-09-30   35.652778  -97.477778
#
# [80332 rows x 11 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 80332 entries, 1949-10-10 20:30:00 to 2013-09-09 23:00:00
# Data columns (total 11 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   date_time                        80332 non-null  object
#  1   city                             80332 non-null  object
#  2   state/province                   74535 non-null  object
#  3   country                          70662 non-null  object
#  4   ufo_shape                        78400 non-null  object
#  5   length_of_encounter_seconds      80332 non-null  object
#  6   described_duration_of_encounter  80332 non-null  object
#  7   description                      80317 non-null  object
#  8   date_documented                  80332 non-null  datetime64[ns]
#  9   latitude                         80332 non-null  object
#  10  longitude                        80332 non-null  float64
# dtypes: datetime64[ns](1), float64(1), object(9)
# memory usage: 7.4+ MB

# %%
df.length_of_encounter_seconds.describe()
# Out:
# count     80332
# unique      536
# top         300
# freq       8635
# Name: length_of_encounter_seconds, dtype: object

# %%
pd.to_numeric(df.latitude)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/_libs/lib.pyx in pandas._libs.lib.maybe_convert_numeric()
#
# ValueError: Unable to parse string "33q.200088"
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# /var/folders/lq/8xyjvtzs5m74h82472673s0h0000gn/T/ipykernel_51809/3492468202.py in <module>
# ----> 1 pd.to_numeric(df.latitude)
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/tools/numeric.py in to_numeric(arg, errors, downcast)
#     183         coerce_numeric = errors not in ("ignore", "raise")
#     184         try:
# --> 185             values, _ = lib.maybe_convert_numeric(
#     186                 values, set(), coerce_numeric=coerce_numeric
#     187             )
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/_libs/lib.pyx in pandas._libs.lib.maybe_convert_numeric()
#
# ValueError: Unable to parse string "33q.200088" at position 43782

# %%
pd.to_numeric(df.length_of_encounter_seconds)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/_libs/lib.pyx in pandas._libs.lib.maybe_convert_numeric()
#
# ValueError: Unable to parse string "2`"
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# /var/folders/lq/8xyjvtzs5m74h82472673s0h0000gn/T/ipykernel_51809/2006217706.py in <module>
# ----> 1 pd.to_numeric(df.length_of_encounter_seconds)
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/tools/numeric.py in to_numeric(arg, errors, downcast)
#     183         coerce_numeric = errors not in ("ignore", "raise")
#     184         try:
# --> 185             values, _ = lib.maybe_convert_numeric(
#     186                 values, set(), coerce_numeric=coerce_numeric
#     187             )
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/_libs/lib.pyx in pandas._libs.lib.maybe_convert_numeric()
#
# ValueError: Unable to parse string "2`" at position 27822

# %%
df.length_of_encounter_seconds.replace(to_replace=r'\.*(`)', value='', inplace=True)

# %%
df.query('length_of_encounter_seconds.str.contains("`")')
# Out:
#              date_time               city state/province country ufo_shape  \
# 27822   2/2/2000 19:33              bouse             az      us       NaN
# 35692  4/10/2005 22:52         santa cruz             ca      us       NaN
# 58591  7/21/2006 13:00  ibague (colombia)            NaN     NaN    circle
#
#       length_of_encounter_seconds described_duration_of_encounter  \
# 27822                          2`              each a few seconds
# 35692                          8`                   eight seconds
# 58591                        0.5`                     1/2 segundo
#
#                                              description date_documented  \
# 27822  Driving through Plomosa Pass towards Bouse Loo...      2000-02-16
# 35692  2 red lights moving together and apart with a ...      2005-04-16
# 58591  Viajaba a 27.000 pies en un avion comercial ve...      2006-10-30
#
#          latitude   longitude
# 27822     33.9325 -114.005000
# 35692  36.9741667 -122.029722
# 58591    4.440663  -75.244141
